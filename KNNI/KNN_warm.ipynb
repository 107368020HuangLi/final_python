# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import tensorflow as tf 
from tensorflow import keras
#from sklearn import cross_validation, ensemble, preprocessing, metrics
#from sklearn.ensemble import RandomForestClassifier   ##分類
from sklearn.ensemble import RandomForestRegressor    ##回歸
from sklearn.metrics import roc_auc_score
#還是要固定訓練資料和測試資料筆數
from sklearn.tree import DecisionTreeClassifier   ##分類

# %%
from fancyimpute import KNN
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import warnings
import seaborn as sns
# %matplotlib inline
pd.options.mode.chained_assignment = None

# %%
import missingno as msno

# %%
train = pd.read_csv('0406KNN_origin.csv')

# %%
#train

# %%
#train.columns

# %%
msno.bar(train)

# %%
msno.heatmap(train)

# %%
msno.dendrogram(train)

# %%
test = pd.read_csv('0406KNN_1/KNN_output_missing_217.csv')

# %%
msno.bar(test)

# %%
msno.heatmap(test)

# %%
msno.dendrogram(test)
