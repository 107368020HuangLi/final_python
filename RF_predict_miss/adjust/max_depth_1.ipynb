# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import tensorflow as tf 
from tensorflow import keras
#from sklearn import cross_validation, ensemble, preprocessing, metrics
from sklearn.ensemble import RandomForestClassifier   ##分類
from sklearn.tree import DecisionTreeClassifier   ##分類
#from sklearn.ensemble import RandomForestRegressor    ##回歸
#from sklearn.metrics import roc_auc_score
import random
from sklearn.ensemble import AdaBoostClassifier   ##分類
#還是要固定訓練資料和測試資料筆數

from sklearn.model_selection import cross_val_score

# %%
dataset_num = 1

# %%
#all_no_miss
train_ori = pd.read_csv('0410RF_train_data_'+str(dataset_num)+'.csv')
test = pd.read_csv('0410RF_test_data_'+str(dataset_num)+'.csv')
combine = pd.concat([train_ori, test] , ignore_index=True)

# %%
combine = pd.get_dummies(data = combine , columns=["occupation","WHERE","PRE_DIAG"])

# %%
train_ori = combine[0:len(train_ori)]
test_ori = combine[len(train_ori):]

# %%
train_feature_ori = train_ori.columns[1:]
train_target_ori = train_ori.columns[0]
train_feature_ori = train_ori[train_feature_ori]
train_y_ori = train_ori[train_target_ori]

# %%
test_feature_ori = test_ori.columns[1:]
test_target_ori = test_ori.columns[0]
test_feature_ori = test_ori[test_feature_ori]
test_y_ori = test_ori[test_target_ori]

# %%
column = pd.read_csv('0410train_data_column.csv')

# %%
for i in range(10):
    result_depth = []
    max_depth_options = [5,10,15,20,None]
    print("第"+str(i+1)+"次")
    for max_depth in max_depth_options:
        model = RandomForestClassifier(25, oob_score = True, n_jobs = -1, max_features = "auto", max_depth =  max_depth)
        model.fit( train_feature_ori , train_y_ori )
        print( max_depth, "option" )
        acc = model.score(test_feature_ori, test_y_ori)
        print( "C-stat:", acc )
        result_depth.append(acc)
        print("")
    #pd.Series(result_depth, max_depth_options).plot(kind="barh",xlim=(.4,.7))
    print("---------------------------")
# Out:
# 第1次
# 5 option
# C-stat: 0.5714285714285714
#
# 10 option
# C-stat: 0.42857142857142855
#
# 15 option
# C-stat: 0.6428571428571429
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第2次
# 5 option
# C-stat: 0.5714285714285714
#
# 10 option
# C-stat: 0.42857142857142855
#
# 15 option
# C-stat: 0.42857142857142855
#
# 20 option
# C-stat: 0.42857142857142855
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第3次
# 5 option
# C-stat: 0.5
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第4次
# 5 option
# C-stat: 0.42857142857142855
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第5次
# 5 option
# C-stat: 0.6428571428571429
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5714285714285714
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.5
#
# ---------------------------
# 第6次
# 5 option
# C-stat: 0.5
#
# 10 option
# C-stat: 0.6428571428571429
#
# 15 option
# C-stat: 0.5714285714285714
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第7次
# 5 option
# C-stat: 0.6428571428571429
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.5
#
# ---------------------------
# 第8次
# 5 option
# C-stat: 0.5
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5
#
# None option
# C-stat: 0.5714285714285714
#
# ---------------------------
# 第9次
# 5 option
# C-stat: 0.5
#
# 10 option
# C-stat: 0.5714285714285714
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5714285714285714
#
# None option
# C-stat: 0.42857142857142855
#
# ---------------------------
# 第10次
# 5 option
# C-stat: 0.42857142857142855
#
# 10 option
# C-stat: 0.5
#
# 15 option
# C-stat: 0.5
#
# 20 option
# C-stat: 0.5
#
# None option
# C-stat: 0.5
#
# ---------------------------
