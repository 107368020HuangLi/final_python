# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import tensorflow as tf 
from tensorflow import keras
from sklearn.metrics import precision_recall_fscore_support as score
from keras.utils import np_utils
from sklearn.utils import shuffle
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
pd.options.mode.chained_assignment = None

# %%
train = pd.read_csv('0505delete.csv')

# %%
#train.boxplot(by = "HOSDAY", figsize=(10,10))

# %%
ax_AGE = sns.boxplot(x="HOSDAY",y="AGE",data = train)
ax_AGE = sns.stripplot(x="HOSDAY",y="AGE",data = train)

# %%
ax_GENDER = sns.boxplot(x="HOSDAY",y="GENDER",data = train)
ax_GENDER = sns.stripplot(x="HOSDAY",y="GENDER",data = train)

# %%
ax_BMI = sns.boxplot(x="HOSDAY",y="BMI",data = train)
ax_BMI = sns.stripplot(x="HOSDAY",y="BMI",data = train)

# %%
vio_BMI = sns.violinplot(x="HOSDAY",y="BMI",data = train, size =10)

# %%
face_BMI = sns.FacetGrid(train, hue = "HOSDAY", size = 6).map(sns.kdeplot, "BMI").add_legend()

# %%
face_2_BMI = sns.FacetGrid(train, hue = "HOSDAY", size = 5).map(plt.scatter, "BMI","AGE").add_legend()

# %%
sns.pairplot(train, hue = "HOSDAY" , size = 10, diag_kind="kde")
